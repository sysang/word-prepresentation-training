# %%
# %matplotlib inline

# %% [markdown]
# How to Apply Doc2Vec to Reproduce the 'Paragraph Vector' paper
# ==============================================================
#
# Shows how to reproduce results of the "Distributed Representation of Sentences and Documents" paper by Le and Mikolov using Gensim.

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# Introduction
# ------------
#
# This guide shows you how to reproduce the results of the paper by `Le and
# Mikolov 2014 <https://arxiv.org/pdf/1405.4053.pdf>`_ using Gensim. While the
# entire paper is worth reading (it's only 9 pages), we will be focusing on
# Section 3.2: "Beyond One Sentence - Sentiment Analysis with the IMDB
# dataset".
#
# This guide follows the following steps:
#
# #. Load the IMDB dataset
# #. Train a variety of Doc2Vec models on the dataset
# #. Evaluate the performance of each model using a logistic regression
# #. Examine some of the results directly:
#
# When examining results, we will look for answers for the following questions:
#
# #. Are inferred vectors close to the precalculated ones?
# #. Do close documents seem more related than distant ones?
# #. Do the word vectors show useful similarities?
# #. Are the word vectors from this dataset any good at analogies?
#
# Load corpus
# -----------
#
# Our data for the tutorial will be the `IMDB archive
# <http://ai.stanford.edu/~amaas/data/sentiment/>`_.
# If you're not familiar with this dataset, then here's a brief intro: it
# contains several thousand movie reviews.
#
# Each review is a single line of text containing multiple sentences, for example:
#
# ```
# One of the best movie-dramas I have ever seen. We do a lot of acting in the
# church and this is one that can be used as a resource that highlights all the
# good things that actors can do in their work. I highly recommend this one,
# especially for those who have an interest in acting, as a "must see."
# ```
#
# These reviews will be the **documents** that we will work with in this tutorial.
# There are 100 thousand reviews in total.
#
# #. 25k reviews for training (12.5k positive, 12.5k negative)
# #. 25k reviews for testing (12.5k positive, 12.5k negative)
# #. 50k unlabeled reviews
#
# Out of 100k reviews, 50k have a label: either positive (the reviewer liked
# the movie) or negative.
# The remaining 50k are unlabeled.
#
# Our first task will be to prepare the dataset.
#
# More specifically, we will:
#
# #. Download the tar.gz file (it's only 84MB, so this shouldn't take too long)
# #. Unpack it and extract each movie review
# #. Split the reviews into training and test datasets
#
# First, let's define a convenient datatype for holding data for a single document:
#
# * words: The text of the document, as a ``list`` of words.
# * tags: Used to keep the index of the document in the entire dataset.
# * split: one of ``train``\ , ``test`` or ``extra``. Determines how the document will be used (for training, testing, etc).
# * sentiment: either 1 (positive), 0 (negative) or None (unlabeled document).
#
# This data type is helpful for later evaluation and reporting.
# In particular, the ``index`` member will help us quickly and easily retrieve the vectors for a document from a model.

# %%
import collections

SentimentDocument = collections.namedtuple('SentimentDocument', 'words tags split sentiment')

# %% [markdown]
# We can now proceed with loading the corpus.

# %%
import io
import re
import tarfile
import os.path

import smart_open
import gensim.utils

def download_dataset(url='http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz'):
    fname = url.split('/')[-1]

    if os.path.isfile(fname):
       return fname

    # Download the file to local storage first.
    # We can't read it on the fly because of
    # https://github.com/RaRe-Technologies/smart_open/issues/331
    with smart_open.open(url, "rb", ignore_ext=True) as fin:
        with smart_open.open(fname, 'wb', ignore_ext=True) as fout:
            while True:
                buf = fin.read(io.DEFAULT_BUFFER_SIZE)
                if not buf:
                    break
                fout.write(buf)

    return fname

def create_sentiment_document(name, text, index):
    _, split, sentiment_str, _ = name.split('/')
    sentiment = {'pos': 1.0, 'neg': 0.0, 'unsup': None}[sentiment_str]

    if sentiment is None:
        split = 'extra'

    tokens = gensim.utils.to_unicode(text).split()
    return SentimentDocument(tokens, [index], split, sentiment)

def extract_documents():
    fname = download_dataset()

    index = 0

    with tarfile.open(fname, mode='r:gz') as tar:
        for member in tar.getmembers():
            if re.match(r'aclImdb/(train|test)/(pos|neg|unsup)/\d+_\d+.txt$', member.name):
                member_bytes = tar.extractfile(member).read()
                member_text = member_bytes.decode('utf-8', errors='replace')
                assert member_text.count('\n') == 0
                yield create_sentiment_document(member.name, member_text, index)
                index += 1

alldocs = list(extract_documents())

# %% [markdown]
# Here's what a single document looks like

# %%
print(alldocs[27])
# Out:
# SentimentDocument(words=['I', 'was', 'looking', 'forward', 'to', 'this', 'movie.', 'Trustworthy', 'actors,', 'interesting', 'plot.', 'Great', 'atmosphere', 'then', '?????', 'IF', 'you', 'are', 'going', 'to', 'attempt', 'something', 'that', 'is', 'meant', 'to', 'encapsulate', 'the', 'meaning', 'of', 'life.', 'First.', 'Know', 'it.', 'OK', 'I', 'did', 'not', 'expect', 'the', 'directors', 'or', 'writers', 'to', 'actually', 'know', 'the', 'meaning', 'but', 'I', 'thought', 'they', 'may', 'have', 'offered', 'crumbs', 'to', 'peck', 'at', 'and', 'treats', 'to', 'add', 'fuel', 'to', 'the', 'fire-Which!', 'they', 'almost', 'did.', 'Things', 'I', "didn't", 'get.', 'A', 'woman', 'wandering', 'around', 'in', 'dark', 'places', 'and', 'lonely', 'car', 'parks', 'alone-oblivious', 'to', 'the', 'consequences.', 'Great', 'riddles', 'that', 'fell', 'by', 'the', 'wayside.', 'The', 'promise', 'of', 'the', 'knowledge', 'therein', 'contained', 'by', 'the', 'original', 'so-called', 'criminal.', 'I', 'had', 'no', 'problem', 'with', 'the', 'budget', 'and', 'enjoyed', 'the', 'suspense.', 'I', 'understood', 'and', 'can', 'wax', 'lyrical', 'about', 'the', 'fool', 'and', 'found', 'Adrian', 'Pauls', 'role', 'crucial', 'and', 'penetrating', 'and', 'then', '?????', 'Basically', 'the', 'story', 'line', 'and', 'the', 'script', 'where', 'good', 'up', 'to', 'a', 'point', 'and', 'that', 'point', 'was', 'the', 'last', '10', 'minutes', 'or', 'so.', 'What?', 'Run', 'out', 'of', 'ideas!', 'Such', 'a', 'pity', 'that', 'this', 'movie', 'had', 'to', 'let', 'us', 'down', 'so', 'badly.', 'It', 'may', 'not', 'comprehend', 'the', 'meaning', 'and', 'I', 'really', 'did', 'not', 'expect', 'the', 'writers', 'to', 'understand', 'it', 'but', 'I', 'was', 'hoping', 'for', 'an', 'intellectual,', 'if', 'not', 'spiritual', 'ride', 'and', 'got', 'a', 'bump', 'in', 'the', 'road'], tags=[27], split='test', sentiment=0.0)

# %% [markdown]
# Extract our documents and split into training/test sets

# %%
train_docs = [doc for doc in alldocs if doc.split == 'train']
test_docs = [doc for doc in alldocs if doc.split == 'test']
print('%d docs: %d train-sentiment, %d test-sentiment' % (len(alldocs), len(train_docs), len(test_docs)))
# Out:
# 100000 docs: 25000 train-sentiment, 25000 test-sentiment

# %% [markdown]
# Set-up Doc2Vec Training & Evaluation Models
# -------------------------------------------
# We approximate the experiment of Le & Mikolov `"Distributed Representations
# of Sentences and Documents"
# <http://cs.stanford.edu/~quocle/paragraph_vector.pdf>`_ with guidance from
# Mikolov's `example go.sh
# <https://groups.google.com/d/msg/word2vec-toolkit/Q49FIrNOQRo/J6KG8mUj45sJ>`_::
#
#     ./word2vec -train ../alldata-id.txt -output vectors.txt -cbow 0 -size 100 -window 10 -negative 5 -hs 0 -sample 1e-4 -threads 40 -binary 0 -iter 20 -min-count 1 -sentence-vectors 1
#
# We vary the following parameter choices:
#
# * 100-dimensional vectors, as the 400-d vectors of the paper take a lot of
#   memory and, in our tests of this task, don't seem to offer much benefit
# * Similarly, frequent word subsampling seems to decrease sentiment-prediction
#   accuracy, so it's left out
# * ``cbow=0`` means skip-gram which is equivalent to the paper's 'PV-DBOW'
#   mode, matched in gensim with ``dm=0``
# * Added to that DBOW model are two DM models, one which averages context
#   vectors (\ ``dm_mean``\ ) and one which concatenates them (\ ``dm_concat``\ ,
#   resulting in a much larger, slower, more data-hungry model)
# * A ``min_count=2`` saves quite a bit of model memory, discarding only words
#   that appear in a single doc (and are thus no more expressive than the
#   unique-to-each doc vectors themselves)

# %%
import multiprocessing
from collections import OrderedDict

import gensim.models.doc2vec
#assert gensim.models.doc2vec.FAST_VERSION > -1, "This will be painfully slow otherwise"

from gensim.models.doc2vec import Doc2Vec

common_kwargs = dict(
    vector_size=100, epochs=20, min_count=2,
    sample=0, workers=multiprocessing.cpu_count(), negative=5, hs=0,
)

simple_models = [
    # PV-DBOW plain
    Doc2Vec(dm=0, **common_kwargs),
    # PV-DM w/ default averaging; a higher starting alpha may improve CBOW/PV-DM modes
    Doc2Vec(dm=1, window=10, alpha=0.05, comment='alpha=0.05', **common_kwargs),
    # PV-DM w/ concatenation - big, slow, experimental mode
    # window=5 (both sides) approximates paper's apparent 10-word total window size
    Doc2Vec(dm=1, dm_concat=1, window=5, **common_kwargs),
]

for model in simple_models:
    model.build_vocab(alldocs)
    print("%s vocabulary scanned & state initialized" % model)

models_by_name = OrderedDict((str(model), model) for model in simple_models)
# Out:
# 2020-09-01 08:50:36,954 : INFO : using concatenative 1100-dimensional layer1
# 2020-09-01 08:50:36,954 : INFO : collecting all words and their counts
# 2020-09-01 08:50:36,955 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2020-09-01 08:50:37,264 : INFO : PROGRESS: at example #10000, processed 2292381 words (7426204/s), 150816 word types, 10000 tags
# 2020-09-01 08:50:37,594 : INFO : PROGRESS: at example #20000, processed 4573645 words (6928108/s), 238497 word types, 20000 tags
# 2020-09-01 08:50:37,930 : INFO : PROGRESS: at example #30000, processed 6865575 words (6828415/s), 312348 word types, 30000 tags
# 2020-09-01 08:50:38,287 : INFO : PROGRESS: at example #40000, processed 9190019 words (6515924/s), 377231 word types, 40000 tags
# 2020-09-01 08:50:38,650 : INFO : PROGRESS: at example #50000, processed 11557847 words (6545275/s), 438729 word types, 50000 tags
# 2020-09-01 08:50:39,010 : INFO : PROGRESS: at example #60000, processed 13899883 words (6511465/s), 493913 word types, 60000 tags
# 2020-09-01 08:50:39,377 : INFO : PROGRESS: at example #70000, processed 16270094 words (6466567/s), 548474 word types, 70000 tags
# 2020-09-01 08:50:39,741 : INFO : PROGRESS: at example #80000, processed 18598876 words (6416682/s), 598272 word types, 80000 tags
# 2020-09-01 08:50:40,103 : INFO : PROGRESS: at example #90000, processed 20916044 words (6399174/s), 646082 word types, 90000 tags
# 2020-09-01 08:50:40,477 : INFO : collected 693922 word types and 100000 unique tags from a corpus of 100000 examples and 23279529 words
# 2020-09-01 08:50:40,477 : INFO : Loading a fresh vocabulary
# 2020-09-01 08:50:41,546 : INFO : effective_min_count=2 retains 265408 unique words (38% of original 693922, drops 428514)
# 2020-09-01 08:50:41,547 : INFO : effective_min_count=2 leaves 22851015 word corpus (98% of original 23279529, drops 428514)
# 2020-09-01 08:50:42,104 : INFO : deleting the raw counts dictionary of 693922 items
# 2020-09-01 08:50:42,116 : INFO : sample=0 downsamples 0 most-common words
# 2020-09-01 08:50:42,117 : INFO : downsampling leaves estimated 22851015 word corpus (100.0% of prior 22851015)
# 2020-09-01 08:50:42,754 : INFO : estimated required memory for 265408 words and 100 dimensions: 385030400 bytes
# 2020-09-01 08:50:42,755 : INFO : resetting layer weights
# 2020-09-01 08:51:30,014 : INFO : collecting all words and their counts
# 2020-09-01 08:51:30,014 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# Doc2Vec(dbow,d100,n5,mc2,t12) vocabulary scanned & state initialized
# 2020-09-01 08:51:30,304 : INFO : PROGRESS: at example #10000, processed 2292381 words (7922493/s), 150816 word types, 10000 tags
# 2020-09-01 08:51:30,612 : INFO : PROGRESS: at example #20000, processed 4573645 words (7418203/s), 238497 word types, 20000 tags
# 2020-09-01 08:51:30,928 : INFO : PROGRESS: at example #30000, processed 6865575 words (7275484/s), 312348 word types, 30000 tags
# 2020-09-01 08:51:31,263 : INFO : PROGRESS: at example #40000, processed 9190019 words (6936175/s), 377231 word types, 40000 tags
# 2020-09-01 08:51:31,604 : INFO : PROGRESS: at example #50000, processed 11557847 words (6964074/s), 438729 word types, 50000 tags
# 2020-09-01 08:51:31,943 : INFO : PROGRESS: at example #60000, processed 13899883 words (6915696/s), 493913 word types, 60000 tags
# 2020-09-01 08:51:32,290 : INFO : PROGRESS: at example #70000, processed 16270094 words (6845134/s), 548474 word types, 70000 tags
# 2020-09-01 08:51:32,632 : INFO : PROGRESS: at example #80000, processed 18598876 words (6822569/s), 598272 word types, 80000 tags
# 2020-09-01 08:51:32,974 : INFO : PROGRESS: at example #90000, processed 20916044 words (6790792/s), 646082 word types, 90000 tags
# 2020-09-01 08:51:33,325 : INFO : collected 693922 word types and 100000 unique tags from a corpus of 100000 examples and 23279529 words
# 2020-09-01 08:51:33,326 : INFO : Loading a fresh vocabulary
# 2020-09-01 08:51:34,465 : INFO : effective_min_count=2 retains 265408 unique words (38% of original 693922, drops 428514)
# 2020-09-01 08:51:34,466 : INFO : effective_min_count=2 leaves 22851015 word corpus (98% of original 23279529, drops 428514)
# 2020-09-01 08:51:35,024 : INFO : deleting the raw counts dictionary of 693922 items
# 2020-09-01 08:51:35,035 : INFO : sample=0 downsamples 0 most-common words
# 2020-09-01 08:51:35,035 : INFO : downsampling leaves estimated 22851015 word corpus (100.0% of prior 22851015)
# 2020-09-01 08:51:35,676 : INFO : estimated required memory for 265408 words and 100 dimensions: 385030400 bytes
# 2020-09-01 08:51:35,677 : INFO : resetting layer weights
# 2020-09-01 08:52:23,227 : INFO : collecting all words and their counts
# 2020-09-01 08:52:23,228 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t12) vocabulary scanned & state initialized
# 2020-09-01 08:52:23,517 : INFO : PROGRESS: at example #10000, processed 2292381 words (7933630/s), 150816 word types, 10000 tags
# 2020-09-01 08:52:23,820 : INFO : PROGRESS: at example #20000, processed 4573645 words (7553316/s), 238497 word types, 20000 tags
# 2020-09-01 08:52:24,130 : INFO : PROGRESS: at example #30000, processed 6865575 words (7416629/s), 312348 word types, 30000 tags
# 2020-09-01 08:52:24,460 : INFO : PROGRESS: at example #40000, processed 9190019 words (7045852/s), 377231 word types, 40000 tags
# 2020-09-01 08:52:24,792 : INFO : PROGRESS: at example #50000, processed 11557847 words (7152896/s), 438729 word types, 50000 tags
# 2020-09-01 08:52:25,126 : INFO : PROGRESS: at example #60000, processed 13899883 words (7027796/s), 493913 word types, 60000 tags
# 2020-09-01 08:52:25,467 : INFO : PROGRESS: at example #70000, processed 16270094 words (6953210/s), 548474 word types, 70000 tags
# 2020-09-01 08:52:25,804 : INFO : PROGRESS: at example #80000, processed 18598876 words (6929856/s), 598272 word types, 80000 tags
# 2020-09-01 08:52:26,140 : INFO : PROGRESS: at example #90000, processed 20916044 words (6904073/s), 646082 word types, 90000 tags
# 2020-09-01 08:52:26,488 : INFO : collected 693922 word types and 100000 unique tags from a corpus of 100000 examples and 23279529 words
# 2020-09-01 08:52:26,489 : INFO : Loading a fresh vocabulary
# 2020-09-01 08:52:27,308 : INFO : effective_min_count=2 retains 265408 unique words (38% of original 693922, drops 428514)
# 2020-09-01 08:52:27,309 : INFO : effective_min_count=2 leaves 22851015 word corpus (98% of original 23279529, drops 428514)
# 2020-09-01 08:52:27,863 : INFO : deleting the raw counts dictionary of 693922 items
# 2020-09-01 08:52:27,874 : INFO : sample=0 downsamples 0 most-common words
# 2020-09-01 08:52:27,875 : INFO : downsampling leaves estimated 22851015 word corpus (100.0% of prior 22851015)
# 2020-09-01 08:52:28,504 : INFO : estimated required memory for 265408 words and 100 dimensions: 1446662400 bytes
# 2020-09-01 08:52:28,504 : INFO : resetting layer weights
# Doc2Vec(dm/c,d100,n5,w5,mc2,t12) vocabulary scanned & state initialized

# %% [markdown]
# Le and Mikolov note that combining a paragraph vector from Distributed Bag of
# Words (DBOW) and Distributed Memory (DM) improves performance. We will
# follow, pairing the models together for evaluation. Here, we concatenate the
# paragraph vectors obtained from each model with the help of a thin wrapper
# class included in a gensim test module. (Note that this a separate, later
# concatenation of output-vectors than the kind of input-window-concatenation
# enabled by the ``dm_concat=1`` mode above.)

# %%
from gensim.test.test_doc2vec import ConcatenatedDoc2Vec
models_by_name['dbow+dmm'] = ConcatenatedDoc2Vec([simple_models[0], simple_models[1]])
models_by_name['dbow+dmc'] = ConcatenatedDoc2Vec([simple_models[0], simple_models[2]])
# Out:
# 2020-09-01 08:53:15,576 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-09-01 08:53:15,577 : INFO : built Dictionary(12 unique tokens: ['computer', 'human', 'interface', 'response', 'survey']...) from 9 documents (total 29 corpus positions)

# %% [markdown]
# Predictive Evaluation Methods
# -----------------------------
#
# Given a document, our ``Doc2Vec`` models output a vector representation of the document.
# How useful is a particular model?
# In case of sentiment analysis, we want the ouput vector to reflect the sentiment in the input document.
# So, in vector space, positive documents should be distant from negative documents.
#
# We train a logistic regression from the training set:
#
#   - regressors (inputs): document vectors from the Doc2Vec model
#   - target (outpus): sentiment labels
#
# So, this logistic regression will be able to predict sentiment given a document vector.
#
# Next, we test our logistic regression on the test set, and measure the rate of errors (incorrect predictions).
# If the document vectors from the Doc2Vec model reflect the actual sentiment well, the error rate will be low.
#
# Therefore, the error rate of the logistic regression is indication of *how well* the given Doc2Vec model represents documents as vectors.
# We can then compare different ``Doc2Vec`` models by looking at their error rates.

# %%
import numpy as np
import statsmodels.api as sm
from random import sample

def logistic_predictor_from_data(train_targets, train_regressors):
    """Fit a statsmodel logistic predictor on supplied data"""
    logit = sm.Logit(train_targets, train_regressors)
    predictor = logit.fit(disp=0)
    # print(predictor.summary())
    return predictor

def error_rate_for_model(test_model, train_set, test_set):
    """Report error rate on test_doc sentiments, using supplied model and train_docs"""

    train_targets = [doc.sentiment for doc in train_set]
    train_regressors = [test_model.docvecs[doc.tags[0]] for doc in train_set]
    train_regressors = sm.add_constant(train_regressors)
    predictor = logistic_predictor_from_data(train_targets, train_regressors)

    test_regressors = [test_model.docvecs[doc.tags[0]] for doc in test_set]
    test_regressors = sm.add_constant(test_regressors)

    # Predict & evaluate
    test_predictions = predictor.predict(test_regressors)
    corrects = sum(np.rint(test_predictions) == [doc.sentiment for doc in test_set])
    errors = len(test_predictions) - corrects
    error_rate = float(errors) / len(test_predictions)
    return (error_rate, errors, len(test_predictions), predictor)

# %% [markdown]
# Bulk Training & Per-Model Evaluation
# ------------------------------------
#
# Note that doc-vector training is occurring on *all* documents of the dataset,
# which includes all TRAIN/TEST/DEV docs.  Because the native document-order
# has similar-sentiment documents in large clumps – which is suboptimal for
# training – we work with once-shuffled copy of the training set.
#
# We evaluate each model's sentiment predictive power based on error rate, and
# the evaluation is done for each model.
#
# (On a 4-core 2.6Ghz Intel Core i7, these 20 passes training and evaluating 3
# main models takes about an hour.)

# %%
from collections import defaultdict
error_rates = defaultdict(lambda: 1.0)  # To selectively print only best errors achieved

# %%
from random import shuffle
shuffled_alldocs = alldocs[:]
shuffle(shuffled_alldocs)

for model in simple_models:
    print("Training %s" % model)
    model.train(shuffled_alldocs, total_examples=len(shuffled_alldocs), epochs=model.epochs)

    print("\nEvaluating %s" % model)
    err_rate, err_count, test_count, predictor = error_rate_for_model(model, train_docs, test_docs)
    error_rates[str(model)] = err_rate
    print("\n%f %s\n" % (err_rate, model))

for model in [models_by_name['dbow+dmm'], models_by_name['dbow+dmc']]:
    print("\nEvaluating %s" % model)
    err_rate, err_count, test_count, predictor = error_rate_for_model(model, train_docs, test_docs)
    error_rates[str(model)] = err_rate
    print("\n%f %s\n" % (err_rate, model))
# Out:
# 2020-09-01 08:53:16,050 : INFO : training model with 12 workers on 265408 vocabulary and 100 features, using sg=1 hs=0 sample=0 negative=5 window=5
# Training Doc2Vec(dbow,d100,n5,mc2,t12)
# 2020-09-01 08:53:17,060 : INFO : EPOCH 1 - PROGRESS: at 6.68% examples, 1532881 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:18,062 : INFO : EPOCH 1 - PROGRESS: at 13.73% examples, 1573074 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:53:19,068 : INFO : EPOCH 1 - PROGRESS: at 20.83% examples, 1585205 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:20,078 : INFO : EPOCH 1 - PROGRESS: at 27.96% examples, 1596417 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:21,081 : INFO : EPOCH 1 - PROGRESS: at 34.98% examples, 1603403 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:22,094 : INFO : EPOCH 1 - PROGRESS: at 42.06% examples, 1605600 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:23,094 : INFO : EPOCH 1 - PROGRESS: at 49.30% examples, 1610257 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:24,102 : INFO : EPOCH 1 - PROGRESS: at 56.27% examples, 1608292 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:53:25,115 : INFO : EPOCH 1 - PROGRESS: at 63.38% examples, 1610856 words/s, in_qsize 24, out_qsize 1
# 2020-09-01 08:53:26,120 : INFO : EPOCH 1 - PROGRESS: at 70.45% examples, 1611614 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:27,127 : INFO : EPOCH 1 - PROGRESS: at 77.61% examples, 1613949 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:28,129 : INFO : EPOCH 1 - PROGRESS: at 84.69% examples, 1612041 words/s, in_qsize 24, out_qsize 1
# 2020-09-01 08:53:29,139 : INFO : EPOCH 1 - PROGRESS: at 91.94% examples, 1614024 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:30,140 : INFO : EPOCH 1 - PROGRESS: at 99.08% examples, 1614280 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:30,209 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 08:53:30,215 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 08:53:30,219 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 08:53:30,223 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 08:53:30,225 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 08:53:30,227 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-09-01 08:53:30,229 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-09-01 08:53:30,235 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-09-01 08:53:30,238 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-09-01 08:53:30,240 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-09-01 08:53:30,240 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-09-01 08:53:30,241 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-09-01 08:53:30,242 : INFO : EPOCH - 1 : training on 23279529 raw words (22951015 effective words) took 14.2s, 1617799 effective words/s
# 2020-09-01 08:53:31,257 : INFO : EPOCH 2 - PROGRESS: at 6.81% examples, 1552724 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:32,260 : INFO : EPOCH 2 - PROGRESS: at 13.97% examples, 1596325 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:33,260 : INFO : EPOCH 2 - PROGRESS: at 21.10% examples, 1604102 words/s, in_qsize 24, out_qsize 0
# 2020-09-01 08:53:34,261 : INFO : EPOCH 2 - PROGRESS: at 28.08% examples, 1606995 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:35,263 : INFO : EPOCH 2 - PROGRESS: at 35.08% examples, 1610024 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:36,271 : INFO : EPOCH 2 - PROGRESS: at 42.06% examples, 1609231 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:37,280 : INFO : EPOCH 2 - PROGRESS: at 49.34% examples, 1612895 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:38,296 : INFO : EPOCH 2 - PROGRESS: at 56.48% examples, 1613838 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:39,300 : INFO : EPOCH 2 - PROGRESS: at 63.57% examples, 1617231 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:40,305 : INFO : EPOCH 2 - PROGRESS: at 70.62% examples, 1616421 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:53:41,317 : INFO : EPOCH 2 - PROGRESS: at 77.75% examples, 1616670 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:42,325 : INFO : EPOCH 2 - PROGRESS: at 84.97% examples, 1616245 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:43,328 : INFO : EPOCH 2 - PROGRESS: at 92.12% examples, 1617152 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:44,331 : INFO : EPOCH 2 - PROGRESS: at 99.20% examples, 1616325 words/s, in_qsize 20, out_qsize 0
# 2020-09-01 08:53:44,381 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 08:53:44,384 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 08:53:44,389 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 08:53:44,393 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 08:53:44,395 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 08:53:44,398 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-09-01 08:53:44,401 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-09-01 08:53:44,407 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-09-01 08:53:44,408 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-09-01 08:53:44,409 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-09-01 08:53:44,412 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-09-01 08:53:44,413 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-09-01 08:53:44,414 : INFO : EPOCH - 2 : training on 23279529 raw words (22951015 effective words) took 14.2s, 1620008 effective words/s
# 2020-09-01 08:53:45,426 : INFO : EPOCH 3 - PROGRESS: at 6.81% examples, 1556764 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:46,435 : INFO : EPOCH 3 - PROGRESS: at 14.01% examples, 1598440 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:47,436 : INFO : EPOCH 3 - PROGRESS: at 21.22% examples, 1611832 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:48,451 : INFO : EPOCH 3 - PROGRESS: at 28.25% examples, 1609075 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:49,458 : INFO : EPOCH 3 - PROGRESS: at 35.29% examples, 1612450 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:50,459 : INFO : EPOCH 3 - PROGRESS: at 42.31% examples, 1614837 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:51,461 : INFO : EPOCH 3 - PROGRESS: at 49.50% examples, 1616317 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:53:52,463 : INFO : EPOCH 3 - PROGRESS: at 56.63% examples, 1619477 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:53,469 : INFO : EPOCH 3 - PROGRESS: at 63.60% examples, 1618693 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:54,471 : INFO : EPOCH 3 - PROGRESS: at 70.74% examples, 1620137 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:55,474 : INFO : EPOCH 3 - PROGRESS: at 77.70% examples, 1618046 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:56,477 : INFO : EPOCH 3 - PROGRESS: at 84.92% examples, 1618141 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:57,481 : INFO : EPOCH 3 - PROGRESS: at 92.03% examples, 1618102 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:53:58,481 : INFO : EPOCH 3 - PROGRESS: at 99.16% examples, 1618065 words/s, in_qsize 20, out_qsize 1
# 2020-09-01 08:53:58,542 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 08:53:58,547 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 08:53:58,551 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 08:53:58,555 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 08:53:58,558 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 08:53:58,560 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-09-01 08:53:58,564 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-09-01 08:53:58,567 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-09-01 08:53:58,570 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-09-01 08:53:58,572 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-09-01 08:53:58,573 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-09-01 08:53:58,573 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-09-01 08:53:58,574 : INFO : EPOCH - 3 : training on 23279529 raw words (22951015 effective words) took 14.2s, 1621323 effective words/s
# 2020-09-01 08:53:59,583 : INFO : EPOCH 4 - PROGRESS: at 6.81% examples, 1561446 words/s, in_qsize 24, out_qsize 0
# 2020-09-01 08:54:00,588 : INFO : EPOCH 4 - PROGRESS: at 13.89% examples, 1590107 words/s, in_qsize 21, out_qsize 2
# 2020-09-01 08:54:01,594 : INFO : EPOCH 4 - PROGRESS: at 21.05% examples, 1599730 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:02,600 : INFO : EPOCH 4 - PROGRESS: at 28.00% examples, 1599144 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:03,605 : INFO : EPOCH 4 - PROGRESS: at 35.03% examples, 1604717 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:04,614 : INFO : EPOCH 4 - PROGRESS: at 42.06% examples, 1606372 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:05,616 : INFO : EPOCH 4 - PROGRESS: at 49.30% examples, 1610439 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:06,618 : INFO : EPOCH 4 - PROGRESS: at 56.26% examples, 1609554 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:07,618 : INFO : EPOCH 4 - PROGRESS: at 63.28% examples, 1612242 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:08,625 : INFO : EPOCH 4 - PROGRESS: at 70.36% examples, 1612446 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:54:09,627 : INFO : EPOCH 4 - PROGRESS: at 77.43% examples, 1613702 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:54:10,649 : INFO : EPOCH 4 - PROGRESS: at 84.64% examples, 1611602 words/s, in_qsize 21, out_qsize 2
# 2020-09-01 08:54:11,650 : INFO : EPOCH 4 - PROGRESS: at 91.86% examples, 1613899 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:12,655 : INFO : EPOCH 4 - PROGRESS: at 98.98% examples, 1613769 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:12,735 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 08:54:12,740 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 08:54:12,746 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 08:54:12,750 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 08:54:12,752 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 08:54:12,754 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-09-01 08:54:12,755 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-09-01 08:54:12,763 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-09-01 08:54:12,765 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-09-01 08:54:12,767 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-09-01 08:54:12,768 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-09-01 08:54:12,771 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-09-01 08:54:12,772 : INFO : EPOCH - 4 : training on 23279529 raw words (22951015 effective words) took 14.2s, 1616985 effective words/s
# 2020-09-01 08:54:13,778 : INFO : EPOCH 5 - PROGRESS: at 6.81% examples, 1565805 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:14,780 : INFO : EPOCH 5 - PROGRESS: at 13.93% examples, 1598753 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:54:15,785 : INFO : EPOCH 5 - PROGRESS: at 21.10% examples, 1606337 words/s, in_qsize 24, out_qsize 0
# 2020-09-01 08:54:16,786 : INFO : EPOCH 5 - PROGRESS: at 28.08% examples, 1608787 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:17,796 : INFO : EPOCH 5 - PROGRESS: at 35.12% examples, 1610878 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:54:18,802 : INFO : EPOCH 5 - PROGRESS: at 42.18% examples, 1613710 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:19,808 : INFO : EPOCH 5 - PROGRESS: at 49.38% examples, 1614593 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:54:20,808 : INFO : EPOCH 5 - PROGRESS: at 56.52% examples, 1618422 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:21,825 : INFO : EPOCH 5 - PROGRESS: at 63.52% examples, 1616939 words/s, in_qsize 21, out_qsize 2
# 2020-09-01 08:54:22,827 : INFO : EPOCH 5 - PROGRESS: at 70.67% examples, 1618553 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:23,839 : INFO : EPOCH 5 - PROGRESS: at 77.75% examples, 1617838 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:24,846 : INFO : EPOCH 5 - PROGRESS: at 84.96% examples, 1617350 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:25,852 : INFO : EPOCH 5 - PROGRESS: at 92.08% examples, 1617230 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:26,853 : INFO : EPOCH 5 - PROGRESS: at 99.20% examples, 1617194 words/s, in_qsize 20, out_qsize 0
# 2020-09-01 08:54:26,906 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 08:54:26,911 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 08:54:26,916 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 08:54:26,921 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 08:54:26,924 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 08:54:26,926 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-09-01 08:54:26,927 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-09-01 08:54:26,929 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-09-01 08:54:26,931 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-09-01 08:54:26,932 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-09-01 08:54:26,936 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-09-01 08:54:26,937 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-09-01 08:54:26,937 : INFO : EPOCH - 5 : training on 23279529 raw words (22951015 effective words) took 14.2s, 1620666 effective words/s
# 2020-09-01 08:54:27,945 : INFO : EPOCH 6 - PROGRESS: at 6.81% examples, 1563676 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:28,945 : INFO : EPOCH 6 - PROGRESS: at 13.89% examples, 1594430 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:54:29,949 : INFO : EPOCH 6 - PROGRESS: at 21.01% examples, 1601059 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:54:30,955 : INFO : EPOCH 6 - PROGRESS: at 28.00% examples, 1602596 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:54:31,959 : INFO : EPOCH 6 - PROGRESS: at 35.08% examples, 1609825 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:32,975 : INFO : EPOCH 6 - PROGRESS: at 42.19% examples, 1611787 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:33,975 : INFO : EPOCH 6 - PROGRESS: at 49.38% examples, 1614156 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:54:34,989 : INFO : EPOCH 6 - PROGRESS: at 56.48% examples, 1614270 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:54:35,996 : INFO : EPOCH 6 - PROGRESS: at 63.52% examples, 1615902 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:37,000 : INFO : EPOCH 6 - PROGRESS: at 70.61% examples, 1616459 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:38,015 : INFO : EPOCH 6 - PROGRESS: at 77.75% examples, 1616298 words/s, in_qsize 24, out_qsize 0
# 2020-09-01 08:54:39,017 : INFO : EPOCH 6 - PROGRESS: at 85.00% examples, 1617506 words/s, in_qsize 21, out_qsize 2
# 2020-09-01 08:54:40,026 : INFO : EPOCH 6 - PROGRESS: at 92.12% examples, 1616770 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:41,027 : INFO : EPOCH 6 - PROGRESS: at 99.29% examples, 1617571 words/s, in_qsize 18, out_qsize 0
# 2020-09-01 08:54:41,075 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 08:54:41,080 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 08:54:41,084 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 08:54:41,087 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 08:54:41,090 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 08:54:41,093 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-09-01 08:54:41,095 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-09-01 08:54:41,097 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-09-01 08:54:41,100 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-09-01 08:54:41,104 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-09-01 08:54:41,105 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-09-01 08:54:41,106 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-09-01 08:54:41,107 : INFO : EPOCH - 6 : training on 23279529 raw words (22951015 effective words) took 14.2s, 1620222 effective words/s
# 2020-09-01 08:54:42,117 : INFO : EPOCH 7 - PROGRESS: at 6.81% examples, 1558879 words/s, in_qsize 24, out_qsize 0
# 2020-09-01 08:54:43,120 : INFO : EPOCH 7 - PROGRESS: at 13.93% examples, 1595159 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:44,127 : INFO : EPOCH 7 - PROGRESS: at 21.10% examples, 1602652 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:54:45,132 : INFO : EPOCH 7 - PROGRESS: at 28.08% examples, 1604179 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:54:46,145 : INFO : EPOCH 7 - PROGRESS: at 35.16% examples, 1608313 words/s, in_qsize 24, out_qsize 1
# 2020-09-01 08:54:47,153 : INFO : EPOCH 7 - PROGRESS: at 42.23% examples, 1611221 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:48,155 : INFO : EPOCH 7 - PROGRESS: at 49.42% examples, 1613249 words/s, in_qsize 24, out_qsize 1
# 2020-09-01 08:54:49,158 : INFO : EPOCH 7 - PROGRESS: at 56.48% examples, 1614209 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:50,160 : INFO : EPOCH 7 - PROGRESS: at 63.53% examples, 1616921 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:51,170 : INFO : EPOCH 7 - PROGRESS: at 70.61% examples, 1616283 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:54:52,176 : INFO : EPOCH 7 - PROGRESS: at 77.70% examples, 1616646 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:53,184 : INFO : EPOCH 7 - PROGRESS: at 84.96% examples, 1616948 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:54,205 : INFO : EPOCH 7 - PROGRESS: at 92.12% examples, 1615654 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:55,214 : INFO : EPOCH 7 - PROGRESS: at 99.33% examples, 1616274 words/s, in_qsize 17, out_qsize 0
# 2020-09-01 08:54:55,239 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 08:54:55,243 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 08:54:55,247 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 08:54:55,250 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 08:54:55,255 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 08:54:55,257 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-09-01 08:54:55,260 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-09-01 08:54:55,265 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-09-01 08:54:55,268 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-09-01 08:54:55,269 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-09-01 08:54:55,273 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-09-01 08:54:55,274 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-09-01 08:54:55,275 : INFO : EPOCH - 7 : training on 23279529 raw words (22951015 effective words) took 14.2s, 1620380 effective words/s
# 2020-09-01 08:54:56,294 : INFO : EPOCH 8 - PROGRESS: at 6.81% examples, 1545757 words/s, in_qsize 21, out_qsize 2
# 2020-09-01 08:54:57,305 : INFO : EPOCH 8 - PROGRESS: at 14.05% examples, 1596488 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:58,318 : INFO : EPOCH 8 - PROGRESS: at 21.26% examples, 1603796 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:54:59,320 : INFO : EPOCH 8 - PROGRESS: at 28.28% examples, 1608517 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:00,322 : INFO : EPOCH 8 - PROGRESS: at 35.33% examples, 1613352 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:01,326 : INFO : EPOCH 8 - PROGRESS: at 42.27% examples, 1611636 words/s, in_qsize 21, out_qsize 2
# 2020-09-01 08:55:02,326 : INFO : EPOCH 8 - PROGRESS: at 49.51% examples, 1615238 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:03,333 : INFO : EPOCH 8 - PROGRESS: at 56.56% examples, 1615438 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:04,340 : INFO : EPOCH 8 - PROGRESS: at 63.53% examples, 1614840 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:05,343 : INFO : EPOCH 8 - PROGRESS: at 70.58% examples, 1614595 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:06,350 : INFO : EPOCH 8 - PROGRESS: at 77.70% examples, 1615771 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:07,362 : INFO : EPOCH 8 - PROGRESS: at 84.96% examples, 1615645 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:08,369 : INFO : EPOCH 8 - PROGRESS: at 92.12% examples, 1616129 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:09,381 : INFO : EPOCH 8 - PROGRESS: at 99.33% examples, 1616331 words/s, in_qsize 17, out_qsize 0
# 2020-09-01 08:55:09,420 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 08:55:09,428 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 08:55:09,434 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 08:55:09,436 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 08:55:09,438 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 08:55:09,440 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-09-01 08:55:09,441 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-09-01 08:55:09,442 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-09-01 08:55:09,445 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-09-01 08:55:09,446 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-09-01 08:55:09,447 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-09-01 08:55:09,448 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-09-01 08:55:09,448 : INFO : EPOCH - 8 : training on 23279529 raw words (22951015 effective words) took 14.2s, 1619773 effective words/s
# 2020-09-01 08:55:10,462 : INFO : EPOCH 9 - PROGRESS: at 6.81% examples, 1554600 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:11,468 : INFO : EPOCH 9 - PROGRESS: at 14.01% examples, 1599661 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:12,468 : INFO : EPOCH 9 - PROGRESS: at 21.10% examples, 1603151 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:13,473 : INFO : EPOCH 9 - PROGRESS: at 28.08% examples, 1604460 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:55:14,477 : INFO : EPOCH 9 - PROGRESS: at 35.12% examples, 1609600 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:15,486 : INFO : EPOCH 9 - PROGRESS: at 42.19% examples, 1611857 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:16,492 : INFO : EPOCH 9 - PROGRESS: at 49.38% examples, 1612881 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:17,496 : INFO : EPOCH 9 - PROGRESS: at 56.48% examples, 1615070 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:18,517 : INFO : EPOCH 9 - PROGRESS: at 63.53% examples, 1614234 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:55:19,518 : INFO : EPOCH 9 - PROGRESS: at 70.74% examples, 1618249 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:20,519 : INFO : EPOCH 9 - PROGRESS: at 77.70% examples, 1616371 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:21,530 : INFO : EPOCH 9 - PROGRESS: at 84.96% examples, 1616418 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:22,540 : INFO : EPOCH 9 - PROGRESS: at 92.12% examples, 1616470 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:23,558 : INFO : EPOCH 9 - PROGRESS: at 99.32% examples, 1616026 words/s, in_qsize 17, out_qsize 0
# 2020-09-01 08:55:23,584 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 08:55:23,587 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 08:55:23,594 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 08:55:23,598 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 08:55:23,601 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 08:55:23,603 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-09-01 08:55:23,604 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-09-01 08:55:23,612 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-09-01 08:55:23,613 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-09-01 08:55:23,615 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-09-01 08:55:23,617 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-09-01 08:55:23,618 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-09-01 08:55:23,618 : INFO : EPOCH - 9 : training on 23279529 raw words (22951015 effective words) took 14.2s, 1620153 effective words/s
# 2020-09-01 08:55:24,627 : INFO : EPOCH 10 - PROGRESS: at 6.81% examples, 1562065 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:25,633 : INFO : EPOCH 10 - PROGRESS: at 13.97% examples, 1598799 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:26,640 : INFO : EPOCH 10 - PROGRESS: at 21.10% examples, 1602222 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:27,643 : INFO : EPOCH 10 - PROGRESS: at 28.12% examples, 1607113 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:28,643 : INFO : EPOCH 10 - PROGRESS: at 35.08% examples, 1608784 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:29,654 : INFO : EPOCH 10 - PROGRESS: at 42.19% examples, 1612411 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:30,655 : INFO : EPOCH 10 - PROGRESS: at 49.38% examples, 1614518 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:31,662 : INFO : EPOCH 10 - PROGRESS: at 56.48% examples, 1615830 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:32,673 : INFO : EPOCH 10 - PROGRESS: at 63.52% examples, 1616733 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:33,675 : INFO : EPOCH 10 - PROGRESS: at 70.67% examples, 1618319 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:34,680 : INFO : EPOCH 10 - PROGRESS: at 77.75% examples, 1618612 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:35,682 : INFO : EPOCH 10 - PROGRESS: at 84.96% examples, 1618827 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:36,693 : INFO : EPOCH 10 - PROGRESS: at 92.08% examples, 1617873 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:37,695 : INFO : EPOCH 10 - PROGRESS: at 99.25% examples, 1618352 words/s, in_qsize 19, out_qsize 0
# 2020-09-01 08:55:37,745 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 08:55:37,748 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 08:55:37,752 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 08:55:37,754 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 08:55:37,757 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 08:55:37,758 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-09-01 08:55:37,766 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-09-01 08:55:37,769 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-09-01 08:55:37,771 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-09-01 08:55:37,773 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-09-01 08:55:37,775 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-09-01 08:55:37,775 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-09-01 08:55:37,776 : INFO : EPOCH - 10 : training on 23279529 raw words (22951015 effective words) took 14.2s, 1621570 effective words/s
# 2020-09-01 08:55:38,786 : INFO : EPOCH 11 - PROGRESS: at 6.81% examples, 1559909 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:39,800 : INFO : EPOCH 11 - PROGRESS: at 14.01% examples, 1595901 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:40,806 : INFO : EPOCH 11 - PROGRESS: at 21.14% examples, 1601154 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:41,818 : INFO : EPOCH 11 - PROGRESS: at 28.25% examples, 1607129 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:42,821 : INFO : EPOCH 11 - PROGRESS: at 35.29% examples, 1612175 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:43,828 : INFO : EPOCH 11 - PROGRESS: at 42.28% examples, 1611287 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:44,830 : INFO : EPOCH 11 - PROGRESS: at 49.47% examples, 1613422 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:55:45,834 : INFO : EPOCH 11 - PROGRESS: at 56.59% examples, 1616618 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:46,838 : INFO : EPOCH 11 - PROGRESS: at 63.52% examples, 1615385 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:47,841 : INFO : EPOCH 11 - PROGRESS: at 70.67% examples, 1616985 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:48,844 : INFO : EPOCH 11 - PROGRESS: at 77.70% examples, 1616856 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:49,845 : INFO : EPOCH 11 - PROGRESS: at 84.83% examples, 1615775 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:50,846 : INFO : EPOCH 11 - PROGRESS: at 91.94% examples, 1616224 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:51,853 : INFO : EPOCH 11 - PROGRESS: at 99.11% examples, 1616282 words/s, in_qsize 21, out_qsize 1
# 2020-09-01 08:55:51,920 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 08:55:51,924 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 08:55:51,929 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 08:55:51,931 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 08:55:51,933 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 08:55:51,935 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-09-01 08:55:51,937 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-09-01 08:55:51,939 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-09-01 08:55:51,942 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-09-01 08:55:51,948 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-09-01 08:55:51,949 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-09-01 08:55:51,950 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-09-01 08:55:51,950 : INFO : EPOCH - 11 : training on 23279529 raw words (22951015 effective words) took 14.2s, 1619666 effective words/s
# 2020-09-01 08:55:52,956 : INFO : EPOCH 12 - PROGRESS: at 6.81% examples, 1565655 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:53,961 : INFO : EPOCH 12 - PROGRESS: at 13.97% examples, 1601671 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:54,972 : INFO : EPOCH 12 - PROGRESS: at 21.14% examples, 1605042 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:55,984 : INFO : EPOCH 12 - PROGRESS: at 28.21% examples, 1608030 words/s, in_qsize 24, out_qsize 0
# 2020-09-01 08:55:56,985 : INFO : EPOCH 12 - PROGRESS: at 35.21% examples, 1611561 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:57,986 : INFO : EPOCH 12 - PROGRESS: at 42.23% examples, 1613895 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:55:58,991 : INFO : EPOCH 12 - PROGRESS: at 49.38% examples, 1613561 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:55:59,992 : INFO : EPOCH 12 - PROGRESS: at 56.52% examples, 1617303 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:01,009 : INFO : EPOCH 12 - PROGRESS: at 63.52% examples, 1615888 words/s, in_qsize 24, out_qsize 0
# 2020-09-01 08:56:02,010 : INFO : EPOCH 12 - PROGRESS: at 70.61% examples, 1616895 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:03,029 : INFO : EPOCH 12 - PROGRESS: at 77.75% examples, 1616113 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:04,031 : INFO : EPOCH 12 - PROGRESS: at 84.96% examples, 1616497 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:05,031 : INFO : EPOCH 12 - PROGRESS: at 92.08% examples, 1617073 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:06,033 : INFO : EPOCH 12 - PROGRESS: at 99.20% examples, 1616963 words/s, in_qsize 20, out_qsize 0
# 2020-09-01 08:56:06,089 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 08:56:06,093 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 08:56:06,099 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 08:56:06,103 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 08:56:06,105 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 08:56:06,106 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-09-01 08:56:06,108 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-09-01 08:56:06,114 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-09-01 08:56:06,115 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-09-01 08:56:06,116 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-09-01 08:56:06,118 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-09-01 08:56:06,120 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-09-01 08:56:06,121 : INFO : EPOCH - 12 : training on 23279529 raw words (22951015 effective words) took 14.2s, 1620079 effective words/s
# 2020-09-01 08:56:07,128 : INFO : EPOCH 13 - PROGRESS: at 6.81% examples, 1565399 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:08,132 : INFO : EPOCH 13 - PROGRESS: at 13.97% examples, 1602516 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:09,136 : INFO : EPOCH 13 - PROGRESS: at 21.05% examples, 1602799 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:56:10,137 : INFO : EPOCH 13 - PROGRESS: at 28.08% examples, 1608093 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:11,138 : INFO : EPOCH 13 - PROGRESS: at 35.08% examples, 1611630 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:12,142 : INFO : EPOCH 13 - PROGRESS: at 42.06% examples, 1611746 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:13,142 : INFO : EPOCH 13 - PROGRESS: at 49.26% examples, 1614098 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:14,149 : INFO : EPOCH 13 - PROGRESS: at 56.27% examples, 1613120 words/s, in_qsize 23, out_qsize 1
# 2020-09-01 08:56:15,153 : INFO : EPOCH 13 - PROGRESS: at 63.37% examples, 1616653 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:56:16,154 : INFO : EPOCH 13 - PROGRESS: at 70.36% examples, 1615551 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:17,162 : INFO : EPOCH 13 - PROGRESS: at 77.52% examples, 1617380 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:18,174 : INFO : EPOCH 13 - PROGRESS: at 84.64% examples, 1614664 words/s, in_qsize 24, out_qsize 1
# 2020-09-01 08:56:19,181 : INFO : EPOCH 13 - PROGRESS: at 91.94% examples, 1617517 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:56:20,184 : INFO : EPOCH 13 - PROGRESS: at 99.03% examples, 1616567 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:20,250 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 08:56:20,254 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 08:56:20,261 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 08:56:20,265 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 08:56:20,269 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 08:56:20,272 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-09-01 08:56:20,273 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-09-01 08:56:20,282 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-09-01 08:56:20,284 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-09-01 08:56:20,286 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-09-01 08:56:20,287 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-09-01 08:56:20,289 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-09-01 08:56:20,289 : INFO : EPOCH - 13 : training on 23279529 raw words (22951015 effective words) took 14.2s, 1620456 effective words/s
# 2020-09-01 08:56:21,299 : INFO : EPOCH 14 - PROGRESS: at 6.81% examples, 1560650 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:22,319 : INFO : EPOCH 14 - PROGRESS: at 14.05% examples, 1597065 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:23,334 : INFO : EPOCH 14 - PROGRESS: at 21.26% examples, 1602904 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:24,339 : INFO : EPOCH 14 - PROGRESS: at 28.25% examples, 1604404 words/s, in_qsize 24, out_qsize 0
# 2020-09-01 08:56:25,349 : INFO : EPOCH 14 - PROGRESS: at 35.34% examples, 1609347 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:56:26,354 : INFO : EPOCH 14 - PROGRESS: at 42.45% examples, 1614532 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:27,374 : INFO : EPOCH 14 - PROGRESS: at 49.59% examples, 1610546 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:28,375 : INFO : EPOCH 14 - PROGRESS: at 56.75% examples, 1615863 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:29,378 : INFO : EPOCH 14 - PROGRESS: at 63.77% examples, 1617095 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:30,385 : INFO : EPOCH 14 - PROGRESS: at 70.85% examples, 1617002 words/s, in_qsize 24, out_qsize 0
# 2020-09-01 08:56:31,387 : INFO : EPOCH 14 - PROGRESS: at 77.96% examples, 1617747 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:32,388 : INFO : EPOCH 14 - PROGRESS: at 85.13% examples, 1617363 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:33,395 : INFO : EPOCH 14 - PROGRESS: at 92.22% examples, 1616232 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:34,397 : INFO : EPOCH 14 - PROGRESS: at 99.32% examples, 1616219 words/s, in_qsize 15, out_qsize 2
# 2020-09-01 08:56:34,425 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 08:56:34,429 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 08:56:34,431 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 08:56:34,435 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 08:56:34,437 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 08:56:34,440 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-09-01 08:56:34,443 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-09-01 08:56:34,449 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-09-01 08:56:34,451 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-09-01 08:56:34,452 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-09-01 08:56:34,454 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-09-01 08:56:34,457 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-09-01 08:56:34,457 : INFO : EPOCH - 14 : training on 23279529 raw words (22951015 effective words) took 14.2s, 1620447 effective words/s
# 2020-09-01 08:56:35,466 : INFO : EPOCH 15 - PROGRESS: at 6.80% examples, 1561915 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:36,471 : INFO : EPOCH 15 - PROGRESS: at 14.01% examples, 1604894 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:37,473 : INFO : EPOCH 15 - PROGRESS: at 21.15% examples, 1608501 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:38,473 : INFO : EPOCH 15 - PROGRESS: at 28.12% examples, 1610505 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:39,480 : INFO : EPOCH 15 - PROGRESS: at 35.12% examples, 1611537 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:40,486 : INFO : EPOCH 15 - PROGRESS: at 42.19% examples, 1614361 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:41,491 : INFO : EPOCH 15 - PROGRESS: at 49.38% examples, 1615335 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:42,499 : INFO : EPOCH 15 - PROGRESS: at 56.48% examples, 1616328 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:43,505 : INFO : EPOCH 15 - PROGRESS: at 63.53% examples, 1618101 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:44,505 : INFO : EPOCH 15 - PROGRESS: at 70.54% examples, 1616931 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:45,507 : INFO : EPOCH 15 - PROGRESS: at 77.65% examples, 1618709 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:46,509 : INFO : EPOCH 15 - PROGRESS: at 84.78% examples, 1617304 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:47,515 : INFO : EPOCH 15 - PROGRESS: at 91.98% examples, 1618467 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:48,519 : INFO : EPOCH 15 - PROGRESS: at 99.16% examples, 1618758 words/s, in_qsize 21, out_qsize 0
# 2020-09-01 08:56:48,581 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 08:56:48,586 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 08:56:48,590 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 08:56:48,593 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 08:56:48,595 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 08:56:48,597 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-09-01 08:56:48,600 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-09-01 08:56:48,604 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-09-01 08:56:48,606 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-09-01 08:56:48,609 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-09-01 08:56:48,610 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-09-01 08:56:48,611 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-09-01 08:56:48,612 : INFO : EPOCH - 15 : training on 23279529 raw words (22951015 effective words) took 14.1s, 1622011 effective words/s
# 2020-09-01 08:56:49,628 : INFO : EPOCH 16 - PROGRESS: at 6.81% examples, 1549862 words/s, in_qsize 24, out_qsize 0
# 2020-09-01 08:56:50,637 : INFO : EPOCH 16 - PROGRESS: at 14.01% examples, 1594939 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:51,643 : INFO : EPOCH 16 - PROGRESS: at 21.15% examples, 1600212 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:52,657 : INFO : EPOCH 16 - PROGRESS: at 28.25% examples, 1606064 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:53,660 : INFO : EPOCH 16 - PROGRESS: at 35.29% examples, 1611013 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:54,668 : INFO : EPOCH 16 - PROGRESS: at 42.27% examples, 1610080 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:55,673 : INFO : EPOCH 16 - PROGRESS: at 49.51% examples, 1612901 words/s, in_qsize 24, out_qsize 0
# 2020-09-01 08:56:56,691 : INFO : EPOCH 16 - PROGRESS: at 56.67% examples, 1614601 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:57,702 : INFO : EPOCH 16 - PROGRESS: at 63.68% examples, 1614425 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:56:58,713 : INFO : EPOCH 16 - PROGRESS: at 70.85% examples, 1616012 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:56:59,713 : INFO : EPOCH 16 - PROGRESS: at 77.91% examples, 1616301 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:57:00,726 : INFO : EPOCH 16 - PROGRESS: at 85.17% examples, 1616056 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:57:01,728 : INFO : EPOCH 16 - PROGRESS: at 92.30% examples, 1616419 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:57:02,730 : INFO : EPOCH 16 - PROGRESS: at 99.40% examples, 1616315 words/s, in_qsize 15, out_qsize 0
# 2020-09-01 08:57:02,760 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 08:57:02,768 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 08:57:02,771 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 08:57:02,773 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 08:57:02,775 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 08:57:02,777 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-09-01 08:57:02,779 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-09-01 08:57:02,783 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-09-01 08:57:02,784 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-09-01 08:57:02,787 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-09-01 08:57:02,788 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-09-01 08:57:02,789 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-09-01 08:57:02,789 : INFO : EPOCH - 16 : training on 23279529 raw words (22951015 effective words) took 14.2s, 1619316 effective words/s
# 2020-09-01 08:57:03,802 : INFO : EPOCH 17 - PROGRESS: at 6.81% examples, 1556632 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:57:04,804 : INFO : EPOCH 17 - PROGRESS: at 13.93% examples, 1593954 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:57:05,807 : INFO : EPOCH 17 - PROGRESS: at 21.05% examples, 1601097 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:57:06,807 : INFO : EPOCH 17 - PROGRESS: at 28.04% examples, 1604821 words/s, in_qsize 24, out_qsize 0
# 2020-09-01 08:57:07,815 : INFO : EPOCH 17 - PROGRESS: at 35.08% examples, 1608750 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:57:08,815 : INFO : EPOCH 17 - PROGRESS: at 42.06% examples, 1610197 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:57:09,834 : INFO : EPOCH 17 - PROGRESS: at 49.38% examples, 1612629 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:57:10,839 : INFO : EPOCH 17 - PROGRESS: at 56.48% examples, 1614664 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:57:11,858 : INFO : EPOCH 17 - PROGRESS: at 63.53% examples, 1614189 words/s, in_qsize 21, out_qsize 2
# 2020-09-01 08:57:12,861 : INFO : EPOCH 17 - PROGRESS: at 70.61% examples, 1614948 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:57:13,867 : INFO : EPOCH 17 - PROGRESS: at 77.70% examples, 1615438 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 08:57:14,868 : INFO : EPOCH 17 - PROGRESS: at 84.92% examples, 1616015 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:57:15,869 : INFO : EPOCH 17 - PROGRESS: at 92.03% examples, 1616591 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 08:57:16,875 : INFO : EPOCH 17 - PROGRESS: at 99.17% examples, 1615949 words/s, in_qsize 20, out_qsize 1
# 2020-09-01 08:57:16,935 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 08:57:16,943 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 08:57:16,945 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 08:57:16,949 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 08:57:16,950 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 08:57:16,951 : INFO : worker thread finished; awaiting finish of 6 more threads
# ...
# 2020-09-01 09:14:59,436 : INFO : EPOCH 17 - PROGRESS: at 70.36% examples, 800914 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:00,453 : INFO : EPOCH 17 - PROGRESS: at 73.89% examples, 800913 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:01,456 : INFO : EPOCH 17 - PROGRESS: at 77.43% examples, 801449 words/s, in_qsize 24, out_qsize 0
# 2020-09-01 09:15:02,469 : INFO : EPOCH 17 - PROGRESS: at 81.03% examples, 801292 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:03,481 : INFO : EPOCH 17 - PROGRESS: at 84.64% examples, 801467 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 09:15:04,489 : INFO : EPOCH 17 - PROGRESS: at 88.21% examples, 802048 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:05,494 : INFO : EPOCH 17 - PROGRESS: at 91.82% examples, 802271 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:06,506 : INFO : EPOCH 17 - PROGRESS: at 95.41% examples, 802362 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:07,524 : INFO : EPOCH 17 - PROGRESS: at 99.03% examples, 802612 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:07,671 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 09:15:07,682 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 09:15:07,685 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 09:15:07,691 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 09:15:07,699 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 09:15:07,703 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-09-01 09:15:07,713 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-09-01 09:15:07,722 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-09-01 09:15:07,723 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-09-01 09:15:07,724 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-09-01 09:15:07,726 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-09-01 09:15:07,731 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-09-01 09:15:07,731 : INFO : EPOCH - 17 : training on 23279529 raw words (22951015 effective words) took 28.5s, 804646 effective words/s
# 2020-09-01 09:15:08,739 : INFO : EPOCH 18 - PROGRESS: at 3.16% examples, 724200 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:09,765 : INFO : EPOCH 18 - PROGRESS: at 6.81% examples, 773450 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:10,792 : INFO : EPOCH 18 - PROGRESS: at 10.46% examples, 789102 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:11,802 : INFO : EPOCH 18 - PROGRESS: at 14.05% examples, 795173 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:12,803 : INFO : EPOCH 18 - PROGRESS: at 17.64% examples, 800818 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:13,812 : INFO : EPOCH 18 - PROGRESS: at 21.26% examples, 802026 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:14,825 : INFO : EPOCH 18 - PROGRESS: at 24.78% examples, 802100 words/s, in_qsize 24, out_qsize 0
# 2020-09-01 09:15:15,844 : INFO : EPOCH 18 - PROGRESS: at 28.30% examples, 801627 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:16,851 : INFO : EPOCH 18 - PROGRESS: at 31.89% examples, 803456 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:17,870 : INFO : EPOCH 18 - PROGRESS: at 35.34% examples, 802827 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:18,878 : INFO : EPOCH 18 - PROGRESS: at 38.84% examples, 804020 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:19,888 : INFO : EPOCH 18 - PROGRESS: at 42.41% examples, 804303 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:20,915 : INFO : EPOCH 18 - PROGRESS: at 46.15% examples, 805629 words/s, in_qsize 24, out_qsize 0
# 2020-09-01 09:15:21,950 : INFO : EPOCH 18 - PROGRESS: at 49.77% examples, 804935 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:22,951 : INFO : EPOCH 18 - PROGRESS: at 53.37% examples, 806667 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:23,952 : INFO : EPOCH 18 - PROGRESS: at 56.84% examples, 806453 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:24,952 : INFO : EPOCH 18 - PROGRESS: at 60.26% examples, 806156 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:25,973 : INFO : EPOCH 18 - PROGRESS: at 63.85% examples, 806532 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:26,979 : INFO : EPOCH 18 - PROGRESS: at 67.36% examples, 806772 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 09:15:27,997 : INFO : EPOCH 18 - PROGRESS: at 70.97% examples, 806787 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:29,002 : INFO : EPOCH 18 - PROGRESS: at 74.53% examples, 806951 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:30,009 : INFO : EPOCH 18 - PROGRESS: at 78.08% examples, 807047 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:31,015 : INFO : EPOCH 18 - PROGRESS: at 81.73% examples, 807356 words/s, in_qsize 24, out_qsize 0
# 2020-09-01 09:15:32,017 : INFO : EPOCH 18 - PROGRESS: at 85.30% examples, 807172 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:33,027 : INFO : EPOCH 18 - PROGRESS: at 88.94% examples, 808141 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 09:15:34,029 : INFO : EPOCH 18 - PROGRESS: at 92.60% examples, 808637 words/s, in_qsize 24, out_qsize 0
# 2020-09-01 09:15:35,038 : INFO : EPOCH 18 - PROGRESS: at 96.16% examples, 808252 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:36,010 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 09:15:36,014 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 09:15:36,021 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 09:15:36,024 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 09:15:36,031 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 09:15:36,034 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-09-01 09:15:36,036 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-09-01 09:15:36,049 : INFO : EPOCH 18 - PROGRESS: at 99.83% examples, 809221 words/s, in_qsize 4, out_qsize 1
# 2020-09-01 09:15:36,051 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-09-01 09:15:36,055 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-09-01 09:15:36,057 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-09-01 09:15:36,059 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-09-01 09:15:36,060 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-09-01 09:15:36,061 : INFO : EPOCH - 18 : training on 23279529 raw words (22951015 effective words) took 28.3s, 810278 effective words/s
# 2020-09-01 09:15:37,075 : INFO : EPOCH 19 - PROGRESS: at 3.35% examples, 761230 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:38,080 : INFO : EPOCH 19 - PROGRESS: at 6.85% examples, 785373 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:39,086 : INFO : EPOCH 19 - PROGRESS: at 10.38% examples, 792916 words/s, in_qsize 24, out_qsize 0
# 2020-09-01 09:15:40,090 : INFO : EPOCH 19 - PROGRESS: at 14.01% examples, 801834 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:41,092 : INFO : EPOCH 19 - PROGRESS: at 17.57% examples, 804121 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:42,092 : INFO : EPOCH 19 - PROGRESS: at 21.23% examples, 807500 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:43,102 : INFO : EPOCH 19 - PROGRESS: at 24.74% examples, 807254 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 09:15:44,111 : INFO : EPOCH 19 - PROGRESS: at 28.25% examples, 807039 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:45,129 : INFO : EPOCH 19 - PROGRESS: at 31.89% examples, 808392 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:46,142 : INFO : EPOCH 19 - PROGRESS: at 35.42% examples, 809615 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:47,146 : INFO : EPOCH 19 - PROGRESS: at 38.89% examples, 809628 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:48,148 : INFO : EPOCH 19 - PROGRESS: at 42.46% examples, 810009 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 09:15:49,157 : INFO : EPOCH 19 - PROGRESS: at 46.15% examples, 811304 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:50,157 : INFO : EPOCH 19 - PROGRESS: at 49.64% examples, 810111 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 09:15:51,166 : INFO : EPOCH 19 - PROGRESS: at 53.28% examples, 811695 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:52,173 : INFO : EPOCH 19 - PROGRESS: at 56.79% examples, 811482 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:53,182 : INFO : EPOCH 19 - PROGRESS: at 60.30% examples, 811617 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:54,186 : INFO : EPOCH 19 - PROGRESS: at 63.89% examples, 812451 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:55,187 : INFO : EPOCH 19 - PROGRESS: at 67.39% examples, 812591 words/s, in_qsize 23, out_qsize 1
# 2020-09-01 09:15:56,187 : INFO : EPOCH 19 - PROGRESS: at 70.97% examples, 812545 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:57,203 : INFO : EPOCH 19 - PROGRESS: at 74.53% examples, 812027 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:58,214 : INFO : EPOCH 19 - PROGRESS: at 78.20% examples, 813036 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:15:59,215 : INFO : EPOCH 19 - PROGRESS: at 81.85% examples, 813265 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:00,228 : INFO : EPOCH 19 - PROGRESS: at 85.50% examples, 813304 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:01,278 : INFO : EPOCH 19 - PROGRESS: at 89.12% examples, 812365 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:02,281 : INFO : EPOCH 19 - PROGRESS: at 92.82% examples, 813029 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:03,284 : INFO : EPOCH 19 - PROGRESS: at 96.47% examples, 813352 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:04,157 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 09:16:04,173 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 09:16:04,177 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 09:16:04,181 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 09:16:04,182 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 09:16:04,184 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-09-01 09:16:04,188 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-09-01 09:16:04,213 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-09-01 09:16:04,215 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-09-01 09:16:04,216 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-09-01 09:16:04,220 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-09-01 09:16:04,222 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-09-01 09:16:04,223 : INFO : EPOCH - 19 : training on 23279529 raw words (22951015 effective words) took 28.2s, 815214 effective words/s
# 2020-09-01 09:16:05,233 : INFO : EPOCH 20 - PROGRESS: at 3.35% examples, 763838 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:06,245 : INFO : EPOCH 20 - PROGRESS: at 6.89% examples, 789110 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:07,265 : INFO : EPOCH 20 - PROGRESS: at 10.46% examples, 794871 words/s, in_qsize 24, out_qsize 0
# 2020-09-01 09:16:08,267 : INFO : EPOCH 20 - PROGRESS: at 14.05% examples, 801259 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:09,295 : INFO : EPOCH 20 - PROGRESS: at 17.69% examples, 803278 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 09:16:10,310 : INFO : EPOCH 20 - PROGRESS: at 21.38% examples, 806359 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:11,314 : INFO : EPOCH 20 - PROGRESS: at 24.95% examples, 808283 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:12,326 : INFO : EPOCH 20 - PROGRESS: at 28.51% examples, 808947 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 09:16:13,327 : INFO : EPOCH 20 - PROGRESS: at 32.12% examples, 811468 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:14,352 : INFO : EPOCH 20 - PROGRESS: at 35.67% examples, 811540 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:15,358 : INFO : EPOCH 20 - PROGRESS: at 39.22% examples, 812894 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:16,363 : INFO : EPOCH 20 - PROGRESS: at 42.81% examples, 812890 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:17,369 : INFO : EPOCH 20 - PROGRESS: at 46.52% examples, 814812 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:18,380 : INFO : EPOCH 20 - PROGRESS: at 50.14% examples, 814827 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:19,393 : INFO : EPOCH 20 - PROGRESS: at 53.74% examples, 815292 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:20,413 : INFO : EPOCH 20 - PROGRESS: at 57.30% examples, 814740 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:21,416 : INFO : EPOCH 20 - PROGRESS: at 60.76% examples, 814482 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:22,437 : INFO : EPOCH 20 - PROGRESS: at 64.34% examples, 814320 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:23,451 : INFO : EPOCH 20 - PROGRESS: at 67.99% examples, 815297 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:24,453 : INFO : EPOCH 20 - PROGRESS: at 71.63% examples, 815572 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:25,454 : INFO : EPOCH 20 - PROGRESS: at 75.19% examples, 815927 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:26,467 : INFO : EPOCH 20 - PROGRESS: at 78.88% examples, 816522 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:27,479 : INFO : EPOCH 20 - PROGRESS: at 82.51% examples, 815966 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:28,488 : INFO : EPOCH 20 - PROGRESS: at 86.11% examples, 815577 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:29,506 : INFO : EPOCH 20 - PROGRESS: at 89.62% examples, 814857 words/s, in_qsize 22, out_qsize 1
# 2020-09-01 09:16:30,520 : INFO : EPOCH 20 - PROGRESS: at 93.41% examples, 815810 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:31,524 : INFO : EPOCH 20 - PROGRESS: at 97.11% examples, 816355 words/s, in_qsize 23, out_qsize 0
# 2020-09-01 09:16:32,222 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-09-01 09:16:32,239 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-09-01 09:16:32,243 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-09-01 09:16:32,246 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-09-01 09:16:32,252 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-09-01 09:16:32,255 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-09-01 09:16:32,257 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-09-01 09:16:32,272 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-09-01 09:16:32,280 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-09-01 09:16:32,288 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-09-01 09:16:32,289 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-09-01 09:16:32,289 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-09-01 09:16:32,289 : INFO : EPOCH - 20 : training on 23279529 raw words (22951015 effective words) took 28.1s, 817979 effective words/s
# 2020-09-01 09:16:32,290 : INFO : training on a 465590580 raw words (459020300 effective words) took 634.7s, 723175 effective words/s
# Evaluating Doc2Vec(dm/c,d100,n5,w5,mc2,t12)
#
# 0.296360 Doc2Vec(dm/c,d100,n5,w5,mc2,t12)
#
#
# Evaluating Doc2Vec(dbow,d100,n5,mc2,t12)+Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t12)
#
# 0.103440 Doc2Vec(dbow,d100,n5,mc2,t12)+Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t12)
#
#
# Evaluating Doc2Vec(dbow,d100,n5,mc2,t12)+Doc2Vec(dm/c,d100,n5,w5,mc2,t12)
#
# 0.105600 Doc2Vec(dbow,d100,n5,mc2,t12)+Doc2Vec(dm/c,d100,n5,w5,mc2,t12)

# %% [markdown]
# Achieved Sentiment-Prediction Accuracy
# --------------------------------------
# Compare error rates achieved, best-to-worst

# %%
print("Err_rate Model")
for rate, name in sorted((rate, name) for name, rate in error_rates.items()):
    print("%f %s" % (rate, name))
# Out:
# Err_rate Model
# 0.103440 Doc2Vec(dbow,d100,n5,mc2,t12)+Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t12)
# 0.103960 Doc2Vec(dbow,d100,n5,mc2,t12)
# 0.105600 Doc2Vec(dbow,d100,n5,mc2,t12)+Doc2Vec(dm/c,d100,n5,w5,mc2,t12)
# 0.169760 Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t12)
# 0.296360 Doc2Vec(dm/c,d100,n5,w5,mc2,t12)

# %% [markdown]
# In our testing, contrary to the results of the paper, on this problem,
# PV-DBOW alone performs as good as anything else. Concatenating vectors from
# different models only sometimes offers a tiny predictive improvement – and
# stays generally close to the best-performing solo model included.
#
# The best results achieved here are just around 10% error rate, still a long
# way from the paper's reported 7.42% error rate.
#
# (Other trials not shown, with larger vectors and other changes, also don't
# come close to the paper's reported value. Others around the net have reported
# a similar inability to reproduce the paper's best numbers. The PV-DM/C mode
# improves a bit with many more training epochs – but doesn't reach parity with
# PV-DBOW.)

# %% [markdown]
# Examining Results
# -----------------
#
# Let's look for answers to the following questions:
#
# #. Are inferred vectors close to the precalculated ones?
# #. Do close documents seem more related than distant ones?
# #. Do the word vectors show useful similarities?
# #. Are the word vectors from this dataset any good at analogies?

# %% [markdown]
# Are inferred vectors close to the precalculated ones?
# -----------------------------------------------------

# %%
#doc_id = np.random.randint(simple_models[0].docvecs.count)# Pick random doc; re-run cell for more examples
doc_id = 40484
print('for doc %d...' % doc_id)
for model in simple_models:
    inferred_docvec = model.infer_vector(alldocs[doc_id].words)
    print('%s:\n %s' % (model, model.docvecs.most_similar([inferred_docvec], topn=3)))
# Out:
# for doc 40484...
# Doc2Vec(dbow,d100,n5,mc2,t12):
#  [(40484, 0.9845091104507446), (68182, 0.6114521622657776), (24699, 0.6026051640510559)]
# Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t12):
#  [(40484, 0.9155202507972717), (39636, 0.6092585325241089), (70206, 0.5715395212173462)]
# Doc2Vec(dm/c,d100,n5,w5,mc2,t12):
#  [(40484, 0.8342512249946594), (57096, 0.4506417512893677), (65944, 0.44313186407089233)]

# %% [markdown]
# for doc 40484...
# Doc2Vec(dbow,d100,n5,mc2,t12):
#  [(40484, 0.9863420128822327), (68182, 0.6269837021827698), (6824, 0.6055160760879517)]
# Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t12):
#  [(40484, 0.9247998595237732), (86187, 0.6025664806365967), (39636, 0.5781896114349365)]
# Doc2Vec(dm/c,d100,n5,w5,mc2,t12):
#  [(40484, 0.8544603586196899), (17126, 0.4431724548339844), (59160, 0.43748584389686584)]

# %% [markdown]
# for doc 40484...
# Doc2Vec(dbow,d100,n5,mc2,t12):
#  [(40484, 0.9875952005386353), (68182, 0.6229878664016724), (6824, 0.6047743558883667)]
# Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t12):
#  [(40484, 0.9151185750961304), (39636, 0.5833958983421326), (39220, 0.5720853805541992)]
# Doc2Vec(dm/c,d100,n5,w5,mc2,t12):
#  [(40484, 0.8362890481948853), (56128, 0.45506563782691956), (43376, 0.4498768746852875)]

# %% [markdown]
# for doc 40484...
# Doc2Vec(dbow,d100,n5,mc2,t12):
#  [(40484, 0.985596776008606), (68182, 0.6207669973373413), (24699, 0.5981945991516113)]
# Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t12):
#  [(40484, 0.9290589094161987), (39636, 0.5834196209907532), (86187, 0.5826824903488159)]
# Doc2Vec(dm/c,d100,n5,w5,mc2,t12):
#  [(40484, 0.7767651081085205), (73876, 0.4356870651245117), (38544, 0.42808622121810913)]

# %% [markdown]
# (Yes, here the stored vector from 20 epochs of training is usually one of the
# closest to a freshly-inferred vector for the same words. Defaults for
# inference may benefit from tuning for each dataset or model parameters.)

# %% [markdown]
# Do close documents seem more related than distant ones?
# -------------------------------------------------------

# %%
import random

doc_id = np.random.randint(simple_models[0].docvecs.count)  # pick random doc, re-run cell for more examples
model = random.choice(simple_models)  # and a random model
sims = model.docvecs.most_similar(doc_id, topn=model.docvecs.count)  # get *all* similar documents
print(u'TARGET (%d): «%s»\n' % (doc_id, ' '.join(alldocs[doc_id].words)))
print(u'SIMILAR/DISSIMILAR DOCS PER MODEL %s:\n' % model)
for label, index in [('MOST', 0), ('MEDIAN', len(sims)//2), ('LEAST', len(sims) - 1)]:
    s = sims[index]
    i = sims[index][0]
    words = ' '.join(alldocs[i].words)
    print(u'%s %s: «%s»\n' % (label, s, words))
# Out:
# TARGET (54781): «I will not forget this movie for the rest of my life! Although the direction is excellent with a very good script and good production values, the performances are the standout aspect of this remarkable film. Alan Arkin and Sondra Locke make the film work and were both nominated for Oscars for their work here. Their scenes are magic, but Arkin is easily the stronger performance of the two. The supporting cast is very good, but Chuck McCann deserves special mention here. A comedian who's work has mainly been very lighthearted, he plays a straight dramatic role here and does a excellent job. A very human, very touching, very emotional film, the last 15-20 minutes will stay with you a very long time. Turner Classic Movies runs this on occasion and it is currently in print. Most highly recommended.»
#
# SIMILAR/DISSIMILAR DOCS PER MODEL Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t12):
#
# MOST (85064, 0.741161584854126): «I think the film had enough humorous moments to make a 30-minute episode of the standard we've come to expect from the TV series. Because I love the TV show so much, my expectations were perhaps too high, but I found most of this movie vexatiously unamusing.»
#
# MEDIAN (22553, 0.4069937765598297): «The saving grace of this film is its humour. Playing up to the strengths of their star, Warner Brothers cast their version of General Custer as a cocky, dashing, irreverent prankster with a romantic streak and an unexpected strain of idealism; it was Robin Hood all over again, and Flynn blossomed in the role. All his best action pictures made use of his talent for mischief and comic timing, and this one was no exception.<br /><br />It also benefits from the return of former co-star Olivia de Havilland, despite an earlier agreement to break the partnership; the part of strong-minded Libby Custer is a better role than the sweet love-interest types she had grown tired of playing for the studio in Flynn's later films, and after seeing the script he had specifically requested de Havilland be cast so that she could do justice to the part. In this final collaboration, she piles all her considerable acting skill into what is, at heart, basically a romping adventure movie, and the screen chemistry is rekindled -- for once, she and Flynn get the chance to develop their characters beyond the initial romance into an old married couple, to equally winning effect.<br /><br />The Flynn/de Havilland pairing and the streak of comedy are what have provided this film's durability, when most of Flynn's other Westerns -- held in such affection by the contemporary American public, although allegedly not by their star -- have long since been forgotten. The action scenes are fairly cursory (despite, ironically, the death of an extra in a fall during one of the filmed charges) and the villains of the piece turn out, schoolboy-fashion, to be the same people who were horrid to Our Hero on his very first day at West Point, and thus continue to frustrate him throughout his career. It cuts down on the cast list, but it's a trifle too morally convenient.<br /><br />However, these are quibbles largely irrelevant to a film that never set out to be more than a rousing piece of entertainment. Ably aided and abetted by a sterling group of supporting players (memorably including Anthony Quinn in an all-but-wordless role as the Sioux leader), Errol Flynn gallops his way through the plot courtesy of his usual arsenal: charmingly sheepish looks, unexpected sweetness, mischievous twinkles, flash-point indignation, cheerful fellowship and sheer high-octane charisma. He's a reckless braggart, but you can't help but like him. And it's hard to go away without the tune of "Garryowen" threading its jaunty way through your ears for many days thereafter.<br /><br />This is one of Flynn's lasting hits; it also contains a surprising amount of good acting amongst the fun, and is a film worthy of being remembered.»
#
# LEAST (46239, 0.032255619764328): «<br /><br />Everything is relative seems to be the main theme from the outset by this set of eleven pieces by eleven directors. That is to say that what might be number one priority for people like Bush, Blair and Company, may not be so for a great many other people, ordinary people. From the opening scene in which an Iranian teacher is trying to impress on her little students the most important thing that has happened, with the result the children are not impressed, as the death of a neighbour and things like that evidently affect them much more closely than anything which may have happened in New York, USA, wherever that is, this series of almost documentary styled pieces establishes that not all things are as equal unto all men as some world leaders would try to prophess. <br /><br />Whereas, obviously, the attack on the WTC was a dastardly event by any yardstick, one does get the impression that both politicians and TV cameramen tend to blow up things out of all proportion - wonderfully manifested in one of these pieces. Would the same reaction at international level have occurred if the attack had been made on Lagos, say, or Djakarta, say, or even on Rio de Janeiro, say? I rather think not. News seems to suffer distortion depending on where things happen: much more TV time is given to an earthquake in Italy, say, than one ten times more destructive in Outer Mongolia, say. Greater distances seem to decrease the magnitude of the disaster. <br /><br />This series of eleven pieces helps to put things in better perspective - or, perhaps I should say, some of the pieces do, as each director with complete freedom has made up his own story, his own translated perspective, such that it is not possible to judge the whole merits, but individually for each eleven-minute segment. <br /><br />In no way should one deduce that this is an anti-American film: that would be a too simple reading of the diverse messages manifested through the segments. However, it is not pro-American either. The eleven segments adopt varied attitudes and the common link - if there is one - is that the disaster of the WTC attack has to be seen in perspective from different view-points. Only then will such people as George Bush even begin to comprehend the planet he is living on. <br /><br />Clearly stated in one segment is a belief of mine I have been harbouring for two years now: America has not learnt the lesson. And the lesson is that the USA has to share this planet with the rest of humanity - not dominate it by ruthless economical persuasion or just plain force. Instead of learning that the USA cannot continue just stamping all over everybody and everywhere, its political leaders, aided and abetted by Blair (and even Aznar) have become even more arrogant and even more intolerant, which is not doing any good to anyone in Afghanistan or Irak at present, let alone much elsewhere. The White House mentality is totally rejectable: the US and UK invaded Irak and caused all the chaos, and so should clear up the mess they caused - not insist on the UN and other nations to delve in with a helping hand and thus find an easy way out of the turmoil. <br /><br />Radical stances adopted by the US (or even Israel) is only going to be met by radical stances from Islamic people, who for years have been gearing up fanatical fundamentalism, if only to cover up their own macho uselessness, i.e., stoning women to death or simply shrouding them from the tops of their heads to the dusty ground. <br /><br />The world is in a terrible mess, fueled by the greed of a few rich countries who seem bent on not seeing or understanding anything from more multilateral perspectives. This film in eleven separate pieces accurately portrays this dismal and dumb posture.»

# %% [markdown]
# Somewhat, in terms of reviewer tone, movie genre, etc... the MOST
# cosine-similar docs usually seem more like the TARGET than the MEDIAN or
# LEAST... especially if the MOST has a cosine-similarity > 0.5. Re-run the
# cell to try another random target document.

# %% [markdown]
# Do the word vectors show useful similarities?
# ---------------------------------------------

# %%
import random

word_models = simple_models[:]

def pick_random_word(model, threshold=10):
    # pick a random word with a suitable number of occurences
    while True:
        word = random.choice(model.wv.index2word)
        if model.wv.vocab[word].count > threshold:
            return word

target_word = pick_random_word(word_models[0])
# or uncomment below line, to just pick a word from the relevant domain:
# target_word = 'comedy/drama'

for model in word_models:
    print('target_word: %r model: %s similar words:' % (target_word, model))
    for i, (word, sim) in enumerate(model.wv.most_similar(target_word, topn=10), 1):
        print('    %d. %.2f %r' % (i, sim, word))
    print()
# Out:
# 2020-09-01 09:16:34,664 : INFO : precomputing L2-norms of word weight vectors
# 2020-09-01 09:16:34,746 : INFO : precomputing L2-norms of word weight vectors
# 2020-09-01 09:16:34,840 : INFO : precomputing L2-norms of word weight vectors
# target_word: 'animate' model: Doc2Vec(dbow,d100,n5,mc2,t12) similar words:
#     1. 0.45 'Carrel'
#     2. 0.42 '1/6'
#     3. 0.42 'Nott.'
#     4. 0.41 "Alice's"
#     5. 0.41 'Russians,'
#     6. 0.41 "Lagoon's"
#     7. 0.40 'sure).<br'
#     8. 0.39 'Carlotto'
#     9. 0.38 'Myrl'
#     10. 0.38 'Chastity'
#
# target_word: 'animate' model: Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t12) similar words:
#     1. 0.67 'adjust'
#     2. 0.66 'attach'
#     3. 0.64 'assess'
#     4. 0.64 'starve'
#     5. 0.63 'adapt'
#     6. 0.63 'respond'
#     7. 0.63 'utilize'
#     8. 0.62 'devote'
#     9. 0.62 'listen'
#     10. 0.62 'allude'
#
# target_word: 'animate' model: Doc2Vec(dm/c,d100,n5,w5,mc2,t12) similar words:
#     1. 0.72 'sew'
#     2. 0.71 'flay'
#     3. 0.71 'recharge'
#     4. 0.70 'oppress'
#     5. 0.69 'stabilize'
#     6. 0.69 'out-do'
#     7. 0.68 'exist;'
#     8. 0.68 'sate'
#     9. 0.68 'hypnotise'
#     10. 0.68 'prolong'

# %% [markdown]
# Do the DBOW words look meaningless? That's because the gensim DBOW model
# doesn't train word vectors – they remain at their random initialized values –
# unless you ask with the ``dbow_words=1`` initialization parameter. Concurrent
# word-training slows DBOW mode significantly, and offers little improvement
# (and sometimes a little worsening) of the error rate on this IMDB
# sentiment-prediction task, but may be appropriate on other tasks, or if you
# also need word-vectors.
#
# Words from DM models tend to show meaningfully similar words when there are
# many examples in the training data (as with 'plot' or 'actor'). (All DM modes
# inherently involve word-vector training concurrent with doc-vector training.)

# %% [markdown]
# Are the word vectors from this dataset any good at analogies?
# -------------------------------------------------------------

# %%
# grab the file if not already local
questions_filename = 'questions-words.txt'
if not os.path.isfile(questions_filename):
    # Download IMDB archive
    print("Downloading analogy questions file...")
    url = u'https://raw.githubusercontent.com/tmikolov/word2vec/master/questions-words.txt'
    with smart_open.open(url, 'rb') as fin:
        with smart_open.open(questions_filename, 'wb') as fout:
            fout.write(fin.read())
assert os.path.isfile(questions_filename), "questions-words.txt unavailable"
print("Success, questions-words.txt is available for next steps.")

# Note: this analysis takes many minutes
for model in word_models:
    score, sections = model.wv.evaluate_word_analogies('questions-words.txt')
    correct, incorrect = len(sections[-1]['correct']), len(sections[-1]['incorrect'])
    print('%s: %0.2f%% correct (%d of %d)' % (model, float(correct*100)/(correct+incorrect), correct, correct+incorrect))
# Out:
# Downloading analogy questions file...
# Success, questions-words.txt is available for next steps.
# 2020-09-01 09:16:36,430 : INFO : Evaluating word analogies for top 300000 words in the model on questions-words.txt
# 2020-09-01 09:16:39,263 : INFO : capital-common-countries: 0.0% (0/420)
# 2020-09-01 09:16:45,383 : INFO : capital-world: 0.0% (0/902)
# 2020-09-01 09:16:45,969 : INFO : currency: 0.0% (0/86)
# 2020-09-01 09:16:56,310 : INFO : city-in-state: 0.0% (0/1510)
# 2020-09-01 09:16:59,763 : INFO : family: 0.0% (0/506)
# 2020-09-01 09:17:06,544 : INFO : gram1-adjective-to-adverb: 0.0% (0/992)
# 2020-09-01 09:17:11,724 : INFO : gram2-opposite: 0.0% (0/756)
# 2020-09-01 09:17:20,709 : INFO : gram3-comparative: 0.0% (0/1332)
# 2020-09-01 09:17:27,866 : INFO : gram4-superlative: 0.0% (0/1056)
# 2020-09-01 09:17:34,733 : INFO : gram5-present-participle: 0.0% (0/992)
# 2020-09-01 09:17:44,678 : INFO : gram6-nationality-adjective: 0.0% (0/1445)
# 2020-09-01 09:17:55,340 : INFO : gram7-past-tense: 0.0% (0/1560)
# 2020-09-01 09:18:03,501 : INFO : gram8-plural: 0.0% (0/1190)
# 2020-09-01 09:18:09,416 : INFO : gram9-plural-verbs: 0.0% (0/870)
# 2020-09-01 09:18:09,418 : INFO : Quadruplets with out-of-vocabulary words: 30.3%
# 2020-09-01 09:18:09,418 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2020-09-01 09:18:09,418 : INFO : Total accuracy: 0.0% (0/13617)
# Doc2Vec(dbow,d100,n5,mc2,t12): 0.00% correct (0 of 13617)
# 2020-09-01 09:18:09,694 : INFO : Evaluating word analogies for top 300000 words in the model on questions-words.txt
# 2020-09-01 09:18:12,480 : INFO : capital-common-countries: 4.0% (17/420)
# 2020-09-01 09:18:18,529 : INFO : capital-world: 0.6% (5/902)
# 2020-09-01 09:18:19,122 : INFO : currency: 0.0% (0/86)
# 2020-09-01 09:18:29,431 : INFO : city-in-state: 0.1% (2/1510)
# 2020-09-01 09:18:33,015 : INFO : family: 37.9% (192/506)
# 2020-09-01 09:18:39,772 : INFO : gram1-adjective-to-adverb: 4.2% (42/992)
# 2020-09-01 09:18:44,911 : INFO : gram2-opposite: 6.1% (46/756)
# 2020-09-01 09:18:53,693 : INFO : gram3-comparative: 51.7% (688/1332)
# 2020-09-01 09:19:01,146 : INFO : gram4-superlative: 23.1% (244/1056)
# 2020-09-01 09:19:08,105 : INFO : gram5-present-participle: 22.7% (225/992)
# 2020-09-01 09:19:18,042 : INFO : gram6-nationality-adjective: 2.9% (42/1445)
# 2020-09-01 09:19:29,181 : INFO : gram7-past-tense: 26.9% (419/1560)
# 2020-09-01 09:19:37,532 : INFO : gram8-plural: 18.7% (223/1190)
# 2020-09-01 09:19:43,677 : INFO : gram9-plural-verbs: 44.6% (388/870)
# 2020-09-01 09:19:43,678 : INFO : Quadruplets with out-of-vocabulary words: 30.3%
# 2020-09-01 09:19:43,678 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2020-09-01 09:19:43,679 : INFO : Total accuracy: 18.6% (2533/13617)
# Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t12): 18.60% correct (2533 of 13617)
# 2020-09-01 09:19:44,371 : INFO : Evaluating word analogies for top 300000 words in the model on questions-words.txt
# 2020-09-01 09:19:47,249 : INFO : capital-common-countries: 2.6% (11/420)
# 2020-09-01 09:19:53,471 : INFO : capital-world: 0.7% (6/902)
# 2020-09-01 09:19:54,059 : INFO : currency: 0.0% (0/86)
# 2020-09-01 09:20:04,256 : INFO : city-in-state: 0.1% (2/1510)
# 2020-09-01 09:20:07,838 : INFO : family: 36.4% (184/506)
# 2020-09-01 09:20:14,737 : INFO : gram1-adjective-to-adverb: 6.6% (65/992)
# 2020-09-01 09:20:19,853 : INFO : gram2-opposite: 5.4% (41/756)
# 2020-09-01 09:20:29,157 : INFO : gram3-comparative: 40.9% (545/1332)
# 2020-09-01 09:20:36,323 : INFO : gram4-superlative: 28.7% (303/1056)
# 2020-09-01 09:20:43,241 : INFO : gram5-present-participle: 35.1% (348/992)
# 2020-09-01 09:20:52,811 : INFO : gram6-nationality-adjective: 1.9% (27/1445)
# 2020-09-01 09:21:03,640 : INFO : gram7-past-tense: 24.9% (389/1560)
# 2020-09-01 09:21:12,166 : INFO : gram8-plural: 9.8% (117/1190)
# 2020-09-01 09:21:18,317 : INFO : gram9-plural-verbs: 47.2% (411/870)
# 2020-09-01 09:21:18,318 : INFO : Quadruplets with out-of-vocabulary words: 30.3%
# 2020-09-01 09:21:18,318 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2020-09-01 09:21:18,318 : INFO : Total accuracy: 18.0% (2449/13617)
# Doc2Vec(dm/c,d100,n5,w5,mc2,t12): 17.98% correct (2449 of 13617)

# %% [markdown]
# Even though this is a tiny, domain-specific dataset, it shows some meager
# capability on the general word analogies – at least for the DM/mean and
# DM/concat models which actually train word vectors. (The untrained
# random-initialized words of the DBOW model of course fail miserably.)

# %%
str(simple_models[1])
# Out:
# 'Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t12)'

# %%
simple_models[1].save('tmp/gensim_models/alpha05_dmm_d100_n5_w10_mc2.bin')
# Out:
# 2020-09-01 10:52:11,347 : INFO : saving Doc2Vec object under tmp/gensim_models/alpha05_dmm_d100_n5_w10_mc2.bin, separately None
# 2020-09-01 10:52:11,348 : INFO : storing np array 'syn1neg' to tmp/gensim_models/alpha05_dmm_d100_n5_w10_mc2.bin.trainables.syn1neg.npy
# 2020-09-01 10:52:11,393 : INFO : storing np array 'vectors' to tmp/gensim_models/alpha05_dmm_d100_n5_w10_mc2.bin.wv.vectors.npy
# 2020-09-01 10:52:11,436 : INFO : storing np array 'vectors_norm' to tmp/gensim_models/alpha05_dmm_d100_n5_w10_mc2.bin.wv.vectors_norm.npy
# 2020-09-01 10:52:12,326 : INFO : saved tmp/gensim_models/alpha05_dmm_d100_n5_w10_mc2.bin
